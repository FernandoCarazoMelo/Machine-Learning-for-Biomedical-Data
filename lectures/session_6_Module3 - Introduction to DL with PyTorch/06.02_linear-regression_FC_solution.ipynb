# %% [markdown]
# ## Gradient Descent and Linear Regression with PyTorch
#
# ### Part 2 of "Deep Learning with Pytorch: Zero to GANs"
#
# This tutorial series is a hands-on beginner-friendly introduction to deep learning using [PyTorch](https://pytorch.org), an open-source neural networks library. These tutorials take a practical and coding-focused approach. The best way to learn the material is to execute the code and experiment with it yourself. Check out the full series here:
#
# 1. [PyTorch Basics: Tensors & Gradients](https://jovian.ai/aakashns/01-pytorch-basics)
# 2. [Gradient Descent & Linear Regression](https://jovian.ai/aakashns/02-linear-regression)
# 3. [Working with Images & Logistic Regression](https://jovian.ai/aakashns/03-logistic-regression)
# 4. [Training Deep Neural Networks on a GPU](https://jovian.ai/aakashns/04-feedforward-nn)
# 5. [Image Classification using Convolutional Neural Networks](https://jovian.ai/aakashns/05-cifar10-cnn)
# 6. [Data Augmentation, Regularization and ResNets](https://jovian.ai/aakashns/05b-cifar10-resnet)
# 7. [Generating Images using Generative Adversarial Networks](https://jovian.ai/aakashns/06b-anime-dcgan/)

# %% [markdown]
# This tutorial covers the following topics:
#
# - Introduction to linear regression and gradient descent
# - Implementing a linear regression model using PyTorch tensors
# - Training a linear regression model using the gradient descent algorithm
# - Implementing gradient descent and linear regression using PyTorch built-in

# %% [markdown]
# Before we begin, we need to install the required libraries. The installation of PyTorch may differ based on your operating system / cloud environment. You can find detailed installation instructions here: https://pytorch.org .

# %%
# Uncomment and run the appropriate command for your operating system, if required
 
# Linux / Binder
# !pip install numpy torch==1.7.0+cpu torchvision==0.8.1+cpu torchaudio==0.7.0 -f https://download.pytorch.org/whl/torch_stable.html
 
# Windows
# !pip install numpy torch==1.7.0+cpu torchvision==0.8.1+cpu torchaudio==0.7.0 -f https://download.pytorch.org/whl/torch_stable.html
 
# MacOS
# !pip install numpy torch torchvision torchaudio
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)
# Collecting torch==1.7.0+cpu
#   Downloading https://download.pytorch.org/whl/cpu/torch-1.7.0%2Bcpu-cp37-cp37m-linux_x86_64.whl (159.3 MB)
#      |████████████████████████████████| 159.3 MB 4.6 kB/s
# Collecting torchvision==0.8.1+cpu
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.8.1%2Bcpu-cp37-cp37m-linux_x86_64.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 39.0 MB/s
# Collecting torchaudio==0.7.0
#   Downloading torchaudio-0.7.0-cp37-cp37m-manylinux1_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 5.4 MB/s
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0+cpu) (3.10.0.2)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0+cpu) (0.16.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.8.1+cpu) (7.1.2)
# Installing collected packages: dataclasses, torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.7.0+cpu which is incompatible.
# Successfully installed dataclasses-0.6 torch-1.7.0+cpu torchaudio-0.7.0 torchvision-0.8.1+cpu

# %% [markdown]
# ## Introduction to Linear Regression
#
# In this tutorial, we'll discuss one of the foundational algorithms in machine learning: *Linear regression*. We'll create a model that predicts crop yields for apples and oranges (*target variables*) by looking at the average temperature, rainfall, and humidity (*input variables or features*) in a region. Here's the training data:
#
# ![linear-regression-training-data](https://i.imgur.com/6Ujttb4.png)
#
# In a linear regression model, each target variable is estimated to be a weighted sum of the input variables, offset by some constant, known as a bias :
#
# ```
# yield_apple  = w11 * temp + w12 * rainfall + w13 * humidity + b1
# yield_orange = w21 * temp + w22 * rainfall + w23 * humidity + b2
# ```
#
# Visually, it means that the yield of apples is a linear or planar function of temperature, rainfall and humidity:
#
# ![linear-regression-graph](https://i.imgur.com/4DJ9f8X.png)

# %% [markdown]
# The *learning* part of linear regression is to figure out a set of weights `w11, w12,... w23, b1 & b2` using the training data, to make accurate predictions for new data. The _learned_ weights will be used to predict the yields for apples and oranges in a new region using the average temperature, rainfall, and humidity for that region.
#
# We'll _train_ our model by adjusting the weights slightly many times to make better predictions, using an optimization technique called *gradient descent*. Let's begin by importing Numpy and PyTorch.

# %%
import numpy as np
import torch

# %% [markdown]
# ## Training data
#
# We can represent the training data using two matrices: `inputs` and `targets`, each with one row per observation, and one column per variable.

# %%
# Input (temp, rainfall, humidity)
inputs = np.array([[73, 67, 43], 
                   [91, 88, 64], 
                   [87, 134, 58], 
                   [102, 43, 37], 
                   [69, 96, 70]], dtype='float32')

# %%
# Targets (apples, oranges)
targets = np.array([[56, 70], 
                    [81, 101], 
                    [119, 133], 
                    [22, 37], 
                    [103, 119]], dtype='float32')

# %% [markdown]
# We've separated the input and target variables because we'll operate on them separately. Also, we've created numpy arrays, because this is typically how you would work with training data: read some CSV files as numpy arrays, do some processing, and then convert them to PyTorch tensors.
#
# Let's convert the arrays to PyTorch tensors.

# %%
# Convert inputs and targets to tensors
inputs = torch.from_numpy(inputs)
targets = torch.from_numpy(targets)
print(inputs)
print(targets)
# Out:
# tensor([[ 73.,  67.,  43.],
#         [ 91.,  88.,  64.],
#         [ 87., 134.,  58.],
#         [102.,  43.,  37.],
#         [ 69.,  96.,  70.]])
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])

# %% [markdown]
# ## Linear regression model from scratch
#
# The weights and biases (`w11, w12,... w23, b1 & b2`) can also be represented as matrices, initialized as random values. The first row of `w` and the first element of `b` are used to predict the first target variable, i.e., yield of apples, and similarly, the second for oranges.

# %%
# Weights and biases
w = torch.randn(2, 3, requires_grad=True)
b = torch.randn(2, requires_grad=True)
print(w)
print(b)
# Out:
# tensor([[ 0.6090, -0.5538,  2.0207],
#         [-0.0829,  0.4004, -1.3667]], requires_grad=True)
# tensor([-0.2106, -0.4038], requires_grad=True)

# %% [markdown]
# `torch.randn` creates a tensor with the given shape, with elements picked randomly from a [normal distribution](https://en.wikipedia.org/wiki/Normal_distribution) with mean 0 and standard deviation 1.
#
# Our *model* is simply a function that performs a matrix multiplication of the `inputs` and the weights `w` (transposed) and adds the bias `b` (replicated for each observation).
#
# ![matrix-mult](https://i.imgur.com/WGXLFvA.png)
#
# We can define the model as follows:

# %%
def model(x):
    return x @ w.t() + b

# %% [markdown]
# `@` represents matrix multiplication in PyTorch, and the `.t` method returns the transpose of a tensor.
#
# The matrix obtained by passing the input data into the model is a set of predictions for the target variables.

# %%
# Generate predictions
preds = model(inputs)
print(preds)
# Out:
# tensor([[ 94.0334, -38.3993],
#         [135.8007, -60.1847],
#         [ 95.7670, -33.2322],
#         [112.8610, -42.2148],
#         [130.0965, -63.3569]], grad_fn=<AddBackward0>)

# %% [markdown]
# Let's compare the predictions of our model with the actual targets.

# %%
# Compare with targets
print(targets)
# Out:
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])

# %% [markdown]
# You can see a big difference between our model's predictions and the actual targets because we've initialized our model with random weights and biases. Obviously, we can't expect a randomly initialized model to *just work*.

# %% [markdown]
# ## Loss function
#
# Before we improve our model, we need a way to evaluate how well our model is performing. We can compare the model's predictions with the actual targets using the following method:
#
# * Calculate the difference between the two matrices (`preds` and `targets`).
# * Square all elements of the difference matrix to remove negative values.
# * Calculate the average of the elements in the resulting matrix.
#
# The result is a single number, known as the **mean squared error** (MSE).

# %%
# MSE loss
def mse(t1, t2):
    diff = t1 - t2
    return torch.sum(diff * diff) / diff.numel()

# %% [markdown]
# `torch.sum` returns the sum of all the elements in a tensor. The `.numel` method of a tensor returns the number of elements in a tensor. Let's compute the mean squared error for the current predictions of our model.

# %%
# Compute loss
loss = mse(preds, targets)
print(loss)
# Out:
# tensor(11887.2490, grad_fn=<DivBackward0>)

# %% [markdown]
# Here’s how we can interpret the result: *On average, each element in the prediction differs from the actual target by the square root of the loss*. And that’s pretty bad, considering the numbers we are trying to predict are themselves in the range 50–200. The result is called the *loss* because it indicates how bad the model is at predicting the target variables. It represents information loss in the model: the lower the loss, the better the model.

# %% [markdown]
# ## Compute gradients
#
# With PyTorch, we can automatically compute the gradient or derivative of the loss w.r.t. to the weights and biases because they have `requires_grad` set to `True`. We'll see how this is useful in just a moment.

# %%
# Compute gradients
loss.backward()

# %% [markdown]
# The gradients are stored in the `.grad` property of the respective tensors. Note that the derivative of the loss w.r.t. the weights matrix is itself a matrix with the same dimensions.

# %% [markdown]
# ## Adjust weights and biases to reduce the loss
#
# The loss is a [quadratic function](https://en.wikipedia.org/wiki/Quadratic_function) of our weights and biases, and our objective is to find the set of weights where the loss is the lowest. If we plot a graph of the loss w.r.t any individual weight or bias element, it will look like the figure shown below. An important insight from calculus is that the gradient indicates the rate of change of the loss, i.e., the loss function's [slope](https://en.wikipedia.org/wiki/Slope) w.r.t. the weights and biases.
#
# If a gradient element is **positive**:
#
# * **increasing** the weight element's value slightly will **increase** the loss
# * **decreasing** the weight element's value slightly will **decrease** the loss
#
# ![postive-gradient](https://i.imgur.com/WLzJ4xP.png)
#
# If a gradient element is **negative**:
#
# * **increasing** the weight element's value slightly will **decrease** the loss
# * **decreasing** the weight element's value slightly will **increase** the loss
#
# ![negative=gradient](https://i.imgur.com/dvG2fxU.png)
#
# The increase or decrease in the loss by changing a weight element is proportional to the gradient of the loss w.r.t. that element. This observation forms the basis of _the gradient descent_ optimization algorithm that we'll use to improve our model (by _descending_ along the _gradient_).
#
# We can subtract from each weight element a small quantity proportional to the derivative of the loss w.r.t. that element to reduce the loss slightly.

# %%
w
w.grad
# Out:
# tensor([[  3375.9009,   2153.1516,   1810.7551],
#         [-11541.1426, -12926.9268,  -8062.8799]])

# %%
with torch.no_grad():
    w -= w.grad * 1e-5
    b -= b.grad * 1e-5

# %% [markdown]
# We multiply the gradients with a very small number (`10^-5` in this case) to ensure that we don't modify the weights by a very large amount. We want to take a small step in the downhill direction of the gradient, not a giant leap. This number is called the *learning rate* of the algorithm.
#
# We use `torch.no_grad` to indicate to PyTorch that we shouldn't track, calculate, or modify gradients while updating the weights and biases.

# %%
# Let's verify that the loss is actually lower
loss = mse(preds, targets)
print(loss)
# Out:
# tensor(11887.2490, grad_fn=<DivBackward0>)

# %% [markdown]
# Before we proceed, we reset the gradients to zero by invoking the `.zero_()` method. We need to do this because PyTorch accumulates gradients. Otherwise, the next time we invoke `.backward` on the loss, the new gradient values are added to the existing gradients, which may lead to unexpected results.

# %%
w.grad.zero_()
b.grad.zero_()
print(w.grad)
print(b.grad)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])
# tensor([0., 0.])

# %% [markdown]
# ## Train the model using gradient descent
#
# As seen above, we reduce the loss and improve our model using the gradient descent optimization algorithm. Thus, we can _train_ the model using the following steps:
#
# 1. Generate predictions
#
# 2. Calculate the loss
#
# 3. Compute gradients w.r.t the weights and biases
#
# 4. Adjust the weights by subtracting a small quantity proportional to the gradient
#
# 5. Reset the gradients to zero
#
# Let's implement the above step by step.

# %%
p = model(inputs)
loss = mse(p, targets)
loss.backward()
with torch.no_grad():
  w -= w.grad * 1e-4
  b -= b.grad * 1e-4
  w.grad.zero_()
  b.grad.zero_()

print(loss)
# Out:
# tensor(8384.2021, grad_fn=<DivBackward0>)

# %%
# Generate predictions
preds = model(inputs)
print(preds)
# Out:
# tensor([[ 50.7461, 150.8342],
#         [ 79.2634, 188.8087],
#         [ 32.9658, 261.9589],
#         [ 65.6718, 144.5568],
#         [ 78.1765, 176.4023]], grad_fn=<AddBackward0>)

# %%
# Calculate the loss
loss = mse(preds, targets)
print(loss)
# Out:
# tensor(5569.4331, grad_fn=<DivBackward0>)

# %%
# Compute gradients
loss.backward()
print(w.grad)
print(b.grad)
# Out:
# tensor([[-1056.9680, -2507.7166, -1089.7664],
#         [ 8008.4917,  8111.8213,  4914.6006]])
# tensor([-14.8353,  92.5122])

# %% [markdown]
# Let's update the weights and biases using the gradients computed above.

# %%
# Adjust weights & reset gradients
with torch.no_grad():
    w -= w.grad * 1e-4
    b -= b.grad * 1e-4
    w.grad.zero_()
    b.grad.zero_()

# %% [markdown]
# Let's take a look at the new weights and biases.

# %%
print(w)
print(b)
# Out:
# tensor([[ 0.3914, -0.4892,  1.9620],
#         [ 0.1734,  0.7828, -1.1122]], requires_grad=True)
# tensor([-0.2127, -0.4002], requires_grad=True)

# %% [markdown]
# With the new weights and biases, the model should have a lower loss.

# %%
# Calculate loss
preds = model(inputs)
loss = mse(preds, targets)
print(loss)
# Out:
# tensor(3779.3462, grad_fn=<DivBackward0>)

# %%
with torch.no_grad():
    w -= w.grad * 1e-4
    b -= b.grad * 1e-4
    w.grad.zero_()
    b.grad.zero_()
 
# Calculate loss
preds = model(inputs)
loss = mse(preds, targets)
print(loss)
loss.backward()
print(targets)
print(preds)
# Out:
# tensor(3779.3462, grad_fn=<DivBackward0>)
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])
# tensor([[ 79.9512,  16.8809],
#         [117.9257,  13.0847],
#         [ 82.0869,  55.0727],
#         [ 91.2696,   9.7961],
#         [117.1735,   8.8588]], grad_fn=<AddBackward0>)

# %% [markdown]
# We have already achieved a significant reduction in the loss merely by adjusting the weights and biases slightly using gradient descent.

# %% [markdown]
# ## Train for multiple epochs
#
# To reduce the loss further, we can repeat the process of adjusting the weights and biases using the gradients multiple times. Each iteration is called an _epoch_. Let's train the model for 100 epochs.

# %%
# Train for 100 epochs
for i in range(100):
    preds = model(inputs)
    loss = mse(preds, targets)
    loss.backward()
    print(loss)
    with torch.no_grad():
        w -= w.grad * 1e-5
        b -= b.grad * 1e-5
        w.grad.zero_()
        b.grad.zero_()
# Out:
# tensor(90.3686, grad_fn=<DivBackward0>)
# tensor(90.1973, grad_fn=<DivBackward0>)
# tensor(90.0265, grad_fn=<DivBackward0>)
# tensor(89.8560, grad_fn=<DivBackward0>)
# tensor(89.6859, grad_fn=<DivBackward0>)
# tensor(89.5162, grad_fn=<DivBackward0>)
# tensor(89.3468, grad_fn=<DivBackward0>)
# tensor(89.1777, grad_fn=<DivBackward0>)
# tensor(89.0090, grad_fn=<DivBackward0>)
# tensor(88.8406, grad_fn=<DivBackward0>)
# tensor(88.6726, grad_fn=<DivBackward0>)
# tensor(88.5051, grad_fn=<DivBackward0>)
# tensor(88.3377, grad_fn=<DivBackward0>)
# tensor(88.1708, grad_fn=<DivBackward0>)
# tensor(88.0043, grad_fn=<DivBackward0>)
# tensor(87.8380, grad_fn=<DivBackward0>)
# tensor(87.6721, grad_fn=<DivBackward0>)
# tensor(87.5066, grad_fn=<DivBackward0>)
# tensor(87.3414, grad_fn=<DivBackward0>)
# tensor(87.1765, grad_fn=<DivBackward0>)
# tensor(87.0120, grad_fn=<DivBackward0>)
# tensor(86.8479, grad_fn=<DivBackward0>)
# tensor(86.6841, grad_fn=<DivBackward0>)
# tensor(86.5205, grad_fn=<DivBackward0>)
# tensor(86.3574, grad_fn=<DivBackward0>)
# tensor(86.1946, grad_fn=<DivBackward0>)
# tensor(86.0322, grad_fn=<DivBackward0>)
# tensor(85.8700, grad_fn=<DivBackward0>)
# tensor(85.7082, grad_fn=<DivBackward0>)
# tensor(85.5467, grad_fn=<DivBackward0>)
# tensor(85.3857, grad_fn=<DivBackward0>)
# tensor(85.2248, grad_fn=<DivBackward0>)
# tensor(85.0643, grad_fn=<DivBackward0>)
# tensor(84.9042, grad_fn=<DivBackward0>)
# tensor(84.7444, grad_fn=<DivBackward0>)
# tensor(84.5849, grad_fn=<DivBackward0>)
# tensor(84.4257, grad_fn=<DivBackward0>)
# tensor(84.2668, grad_fn=<DivBackward0>)
# tensor(84.1084, grad_fn=<DivBackward0>)
# tensor(83.9502, grad_fn=<DivBackward0>)
# tensor(83.7924, grad_fn=<DivBackward0>)
# tensor(83.6347, grad_fn=<DivBackward0>)
# tensor(83.4776, grad_fn=<DivBackward0>)
# tensor(83.3207, grad_fn=<DivBackward0>)
# tensor(83.1641, grad_fn=<DivBackward0>)
# tensor(83.0078, grad_fn=<DivBackward0>)
# tensor(82.8519, grad_fn=<DivBackward0>)
# tensor(82.6963, grad_fn=<DivBackward0>)
# tensor(82.5409, grad_fn=<DivBackward0>)
# tensor(82.3860, grad_fn=<DivBackward0>)
# tensor(82.2312, grad_fn=<DivBackward0>)
# tensor(82.0768, grad_fn=<DivBackward0>)
# tensor(81.9228, grad_fn=<DivBackward0>)
# tensor(81.7690, grad_fn=<DivBackward0>)
# tensor(81.6156, grad_fn=<DivBackward0>)
# tensor(81.4624, grad_fn=<DivBackward0>)
# tensor(81.3097, grad_fn=<DivBackward0>)
# tensor(81.1571, grad_fn=<DivBackward0>)
# tensor(81.0050, grad_fn=<DivBackward0>)
# tensor(80.8530, grad_fn=<DivBackward0>)
# tensor(80.7014, grad_fn=<DivBackward0>)
# tensor(80.5501, grad_fn=<DivBackward0>)
# tensor(80.3991, grad_fn=<DivBackward0>)
# tensor(80.2484, grad_fn=<DivBackward0>)
# tensor(80.0980, grad_fn=<DivBackward0>)
# tensor(79.9479, grad_fn=<DivBackward0>)
# tensor(79.7982, grad_fn=<DivBackward0>)
# tensor(79.6486, grad_fn=<DivBackward0>)
# tensor(79.4994, grad_fn=<DivBackward0>)
# tensor(79.3506, grad_fn=<DivBackward0>)
# tensor(79.2020, grad_fn=<DivBackward0>)
# tensor(79.0537, grad_fn=<DivBackward0>)
# tensor(78.9056, grad_fn=<DivBackward0>)
# tensor(78.7579, grad_fn=<DivBackward0>)
# tensor(78.6105, grad_fn=<DivBackward0>)
# tensor(78.4634, grad_fn=<DivBackward0>)
# tensor(78.3166, grad_fn=<DivBackward0>)
# tensor(78.1700, grad_fn=<DivBackward0>)
# tensor(78.0238, grad_fn=<DivBackward0>)
# tensor(77.8777, grad_fn=<DivBackward0>)
# tensor(77.7321, grad_fn=<DivBackward0>)
# tensor(77.5867, grad_fn=<DivBackward0>)
# tensor(77.4417, grad_fn=<DivBackward0>)
# tensor(77.2968, grad_fn=<DivBackward0>)
# tensor(77.1523, grad_fn=<DivBackward0>)
# tensor(77.0080, grad_fn=<DivBackward0>)
# tensor(76.8642, grad_fn=<DivBackward0>)
# tensor(76.7204, grad_fn=<DivBackward0>)
# tensor(76.5771, grad_fn=<DivBackward0>)
# tensor(76.4339, grad_fn=<DivBackward0>)
# tensor(76.2910, grad_fn=<DivBackward0>)
# tensor(76.1485, grad_fn=<DivBackward0>)
# tensor(76.0062, grad_fn=<DivBackward0>)
# tensor(75.8643, grad_fn=<DivBackward0>)
# tensor(75.7226, grad_fn=<DivBackward0>)
# tensor(75.5811, grad_fn=<DivBackward0>)
# tensor(75.4400, grad_fn=<DivBackward0>)
# tensor(75.2991, grad_fn=<DivBackward0>)
# tensor(75.1586, grad_fn=<DivBackward0>)
# tensor(75.0182, grad_fn=<DivBackward0>)
# tensor(74.8782, grad_fn=<DivBackward0>)
# tensor(74.7383, grad_fn=<DivBackward0>)
# tensor(74.5989, grad_fn=<DivBackward0>)
# tensor(74.4597, grad_fn=<DivBackward0>)
# tensor(74.3207, grad_fn=<DivBackward0>)
# tensor(74.1820, grad_fn=<DivBackward0>)
# tensor(74.0436, grad_fn=<DivBackward0>)
# tensor(73.9055, grad_fn=<DivBackward0>)
# tensor(73.7675, grad_fn=<DivBackward0>)
# tensor(73.6300, grad_fn=<DivBackward0>)
# tensor(73.4926, grad_fn=<DivBackward0>)
# tensor(73.3555, grad_fn=<DivBackward0>)
# tensor(73.2187, grad_fn=<DivBackward0>)
# tensor(73.0822, grad_fn=<DivBackward0>)
# tensor(72.9459, grad_fn=<DivBackward0>)
# tensor(72.8100, grad_fn=<DivBackward0>)
# tensor(72.6741, grad_fn=<DivBackward0>)
# tensor(72.5387, grad_fn=<DivBackward0>)
# tensor(72.4034, grad_fn=<DivBackward0>)
# tensor(72.2685, grad_fn=<DivBackward0>)
# tensor(72.1338, grad_fn=<DivBackward0>)
# tensor(71.9994, grad_fn=<DivBackward0>)
# tensor(71.8652, grad_fn=<DivBackward0>)
# tensor(71.7313, grad_fn=<DivBackward0>)
# tensor(71.5977, grad_fn=<DivBackward0>)
# tensor(71.4643, grad_fn=<DivBackward0>)
# tensor(71.3311, grad_fn=<DivBackward0>)
# tensor(71.1983, grad_fn=<DivBackward0>)
# tensor(71.0656, grad_fn=<DivBackward0>)
# tensor(70.9332, grad_fn=<DivBackward0>)
# tensor(70.8012, grad_fn=<DivBackward0>)
# tensor(70.6693, grad_fn=<DivBackward0>)
# tensor(70.5377, grad_fn=<DivBackward0>)
# tensor(70.4063, grad_fn=<DivBackward0>)
# tensor(70.2753, grad_fn=<DivBackward0>)
# tensor(70.1444, grad_fn=<DivBackward0>)
# tensor(70.0139, grad_fn=<DivBackward0>)
# tensor(69.8835, grad_fn=<DivBackward0>)
# tensor(69.7534, grad_fn=<DivBackward0>)
# tensor(69.6236, grad_fn=<DivBackward0>)
# tensor(69.4941, grad_fn=<DivBackward0>)
# tensor(69.3647, grad_fn=<DivBackward0>)
# tensor(69.2356, grad_fn=<DivBackward0>)
# tensor(69.1067, grad_fn=<DivBackward0>)
# tensor(68.9782, grad_fn=<DivBackward0>)
# tensor(68.8498, grad_fn=<DivBackward0>)
# tensor(68.7218, grad_fn=<DivBackward0>)
# tensor(68.5939, grad_fn=<DivBackward0>)
# tensor(68.4663, grad_fn=<DivBackward0>)
# tensor(68.3389, grad_fn=<DivBackward0>)
# tensor(68.2118, grad_fn=<DivBackward0>)
# tensor(68.0849, grad_fn=<DivBackward0>)
# tensor(67.9583, grad_fn=<DivBackward0>)
# tensor(67.8319, grad_fn=<DivBackward0>)
# tensor(67.7058, grad_fn=<DivBackward0>)
# tensor(67.5798, grad_fn=<DivBackward0>)
# tensor(67.4542, grad_fn=<DivBackward0>)
# tensor(67.3288, grad_fn=<DivBackward0>)
# tensor(67.2036, grad_fn=<DivBackward0>)
# tensor(67.0787, grad_fn=<DivBackward0>)
# tensor(66.9540, grad_fn=<DivBackward0>)
# tensor(66.8296, grad_fn=<DivBackward0>)
# tensor(66.7053, grad_fn=<DivBackward0>)
# tensor(66.5813, grad_fn=<DivBackward0>)
# tensor(66.4576, grad_fn=<DivBackward0>)
# tensor(66.3341, grad_fn=<DivBackward0>)
# tensor(66.2108, grad_fn=<DivBackward0>)
# tensor(66.0877, grad_fn=<DivBackward0>)
# tensor(65.9650, grad_fn=<DivBackward0>)
# tensor(65.8423, grad_fn=<DivBackward0>)
# tensor(65.7201, grad_fn=<DivBackward0>)
# tensor(65.5979, grad_fn=<DivBackward0>)
# tensor(65.4760, grad_fn=<DivBackward0>)
# tensor(65.3544, grad_fn=<DivBackward0>)
# tensor(65.2330, grad_fn=<DivBackward0>)
# tensor(65.1119, grad_fn=<DivBackward0>)
# tensor(64.9909, grad_fn=<DivBackward0>)
# tensor(64.8702, grad_fn=<DivBackward0>)
# tensor(64.7497, grad_fn=<DivBackward0>)
# tensor(64.6295, grad_fn=<DivBackward0>)
# tensor(64.5094, grad_fn=<DivBackward0>)
# tensor(64.3896, grad_fn=<DivBackward0>)
# tensor(64.2701, grad_fn=<DivBackward0>)
# tensor(64.1508, grad_fn=<DivBackward0>)
# tensor(64.0316, grad_fn=<DivBackward0>)
# tensor(63.9128, grad_fn=<DivBackward0>)
# tensor(63.7940, grad_fn=<DivBackward0>)
# tensor(63.6756, grad_fn=<DivBackward0>)
# tensor(63.5575, grad_fn=<DivBackward0>)
# tensor(63.4395, grad_fn=<DivBackward0>)
# tensor(63.3217, grad_fn=<DivBackward0>)
# tensor(63.2041, grad_fn=<DivBackward0>)
# tensor(63.0869, grad_fn=<DivBackward0>)
# tensor(62.9697, grad_fn=<DivBackward0>)
# tensor(62.8529, grad_fn=<DivBackward0>)
# tensor(62.7362, grad_fn=<DivBackward0>)
# tensor(62.6199, grad_fn=<DivBackward0>)
# tensor(62.5036, grad_fn=<DivBackward0>)
# tensor(62.3876, grad_fn=<DivBackward0>)
# tensor(62.2719, grad_fn=<DivBackward0>)
# tensor(62.1563, grad_fn=<DivBackward0>)
# tensor(62.0410, grad_fn=<DivBackward0>)
# tensor(61.9259, grad_fn=<DivBackward0>)
# tensor(61.8111, grad_fn=<DivBackward0>)
# tensor(61.6963, grad_fn=<DivBackward0>)
# tensor(61.5819, grad_fn=<DivBackward0>)
# tensor(61.4677, grad_fn=<DivBackward0>)
# tensor(61.3536, grad_fn=<DivBackward0>)
# tensor(61.2398, grad_fn=<DivBackward0>)
# tensor(61.1262, grad_fn=<DivBackward0>)
# tensor(61.0129, grad_fn=<DivBackward0>)
# tensor(60.8998, grad_fn=<DivBackward0>)
# tensor(60.7868, grad_fn=<DivBackward0>)
# tensor(60.6741, grad_fn=<DivBackward0>)
# tensor(60.5616, grad_fn=<DivBackward0>)
# tensor(60.4492, grad_fn=<DivBackward0>)
# tensor(60.3372, grad_fn=<DivBackward0>)
# tensor(60.2253, grad_fn=<DivBackward0>)
# tensor(60.1136, grad_fn=<DivBackward0>)
# tensor(60.0022, grad_fn=<DivBackward0>)
# tensor(59.8909, grad_fn=<DivBackward0>)
# tensor(59.7799, grad_fn=<DivBackward0>)
# tensor(59.6690, grad_fn=<DivBackward0>)
# tensor(59.5585, grad_fn=<DivBackward0>)
# tensor(59.4481, grad_fn=<DivBackward0>)
# tensor(59.3379, grad_fn=<DivBackward0>)
# tensor(59.2279, grad_fn=<DivBackward0>)
# tensor(59.1180, grad_fn=<DivBackward0>)
# tensor(59.0085, grad_fn=<DivBackward0>)
# tensor(58.8991, grad_fn=<DivBackward0>)
# tensor(58.7900, grad_fn=<DivBackward0>)
# tensor(58.6810, grad_fn=<DivBackward0>)
# tensor(58.5724, grad_fn=<DivBackward0>)
# tensor(58.4638, grad_fn=<DivBackward0>)
# tensor(58.3554, grad_fn=<DivBackward0>)
# tensor(58.2473, grad_fn=<DivBackward0>)
# tensor(58.1393, grad_fn=<DivBackward0>)
# tensor(58.0317, grad_fn=<DivBackward0>)
# tensor(57.9241, grad_fn=<DivBackward0>)
# tensor(57.8168, grad_fn=<DivBackward0>)
# tensor(57.7096, grad_fn=<DivBackward0>)
# tensor(57.6027, grad_fn=<DivBackward0>)
# tensor(57.4960, grad_fn=<DivBackward0>)
# tensor(57.3896, grad_fn=<DivBackward0>)
# tensor(57.2833, grad_fn=<DivBackward0>)
# tensor(57.1771, grad_fn=<DivBackward0>)
# tensor(57.0712, grad_fn=<DivBackward0>)
# tensor(56.9654, grad_fn=<DivBackward0>)
# tensor(56.8600, grad_fn=<DivBackward0>)
# tensor(56.7547, grad_fn=<DivBackward0>)
# tensor(56.6495, grad_fn=<DivBackward0>)
# tensor(56.5446, grad_fn=<DivBackward0>)
# tensor(56.4399, grad_fn=<DivBackward0>)
# tensor(56.3354, grad_fn=<DivBackward0>)
# tensor(56.2311, grad_fn=<DivBackward0>)
# tensor(56.1269, grad_fn=<DivBackward0>)
# tensor(56.0230, grad_fn=<DivBackward0>)
# tensor(55.9192, grad_fn=<DivBackward0>)
# tensor(55.8157, grad_fn=<DivBackward0>)
# tensor(55.7123, grad_fn=<DivBackward0>)
# tensor(55.6093, grad_fn=<DivBackward0>)
# tensor(55.5063, grad_fn=<DivBackward0>)
# tensor(55.4035, grad_fn=<DivBackward0>)
# tensor(55.3010, grad_fn=<DivBackward0>)
# tensor(55.1985, grad_fn=<DivBackward0>)
# tensor(55.0964, grad_fn=<DivBackward0>)
# tensor(54.9944, grad_fn=<DivBackward0>)
# tensor(54.8926, grad_fn=<DivBackward0>)
# tensor(54.7909, grad_fn=<DivBackward0>)
# tensor(54.6896, grad_fn=<DivBackward0>)
# tensor(54.5883, grad_fn=<DivBackward0>)
# tensor(54.4873, grad_fn=<DivBackward0>)
# tensor(54.3864, grad_fn=<DivBackward0>)
# tensor(54.2857, grad_fn=<DivBackward0>)
# tensor(54.1853, grad_fn=<DivBackward0>)
# tensor(54.0850, grad_fn=<DivBackward0>)
# tensor(53.9849, grad_fn=<DivBackward0>)
# tensor(53.8850, grad_fn=<DivBackward0>)
# tensor(53.7853, grad_fn=<DivBackward0>)
# tensor(53.6859, grad_fn=<DivBackward0>)
# tensor(53.5864, grad_fn=<DivBackward0>)
# tensor(53.4873, grad_fn=<DivBackward0>)
# tensor(53.3883, grad_fn=<DivBackward0>)
# tensor(53.2895, grad_fn=<DivBackward0>)
# tensor(53.1910, grad_fn=<DivBackward0>)
# tensor(53.0925, grad_fn=<DivBackward0>)
# tensor(52.9943, grad_fn=<DivBackward0>)
# tensor(52.8962, grad_fn=<DivBackward0>)
# tensor(52.7984, grad_fn=<DivBackward0>)
# tensor(52.7008, grad_fn=<DivBackward0>)
# tensor(52.6032, grad_fn=<DivBackward0>)
# tensor(52.5059, grad_fn=<DivBackward0>)
# tensor(52.4088, grad_fn=<DivBackward0>)
# tensor(52.3119, grad_fn=<DivBackward0>)
# tensor(52.2151, grad_fn=<DivBackward0>)
# tensor(52.1185, grad_fn=<DivBackward0>)
# tensor(52.0221, grad_fn=<DivBackward0>)
# tensor(51.9259, grad_fn=<DivBackward0>)
# tensor(51.8299, grad_fn=<DivBackward0>)
# tensor(51.7340, grad_fn=<DivBackward0>)
# tensor(51.6384, grad_fn=<DivBackward0>)
# tensor(51.5429, grad_fn=<DivBackward0>)
# tensor(51.4476, grad_fn=<DivBackward0>)
# tensor(51.3524, grad_fn=<DivBackward0>)
# tensor(51.2574, grad_fn=<DivBackward0>)
# tensor(51.1627, grad_fn=<DivBackward0>)
# tensor(51.0681, grad_fn=<DivBackward0>)
# tensor(50.9736, grad_fn=<DivBackward0>)
# tensor(50.8794, grad_fn=<DivBackward0>)
# tensor(50.7853, grad_fn=<DivBackward0>)
# tensor(50.6914, grad_fn=<DivBackward0>)
# tensor(50.5977, grad_fn=<DivBackward0>)
# tensor(50.5041, grad_fn=<DivBackward0>)
# tensor(50.4108, grad_fn=<DivBackward0>)
# tensor(50.3176, grad_fn=<DivBackward0>)
# tensor(50.2246, grad_fn=<DivBackward0>)
# tensor(50.1317, grad_fn=<DivBackward0>)
# tensor(50.0391, grad_fn=<DivBackward0>)
# tensor(49.9466, grad_fn=<DivBackward0>)
# tensor(49.8543, grad_fn=<DivBackward0>)
# tensor(49.7621, grad_fn=<DivBackward0>)
# tensor(49.6701, grad_fn=<DivBackward0>)
# tensor(49.5783, grad_fn=<DivBackward0>)
# tensor(49.4867, grad_fn=<DivBackward0>)
# tensor(49.3953, grad_fn=<DivBackward0>)
# tensor(49.3040, grad_fn=<DivBackward0>)
# tensor(49.2128, grad_fn=<DivBackward0>)
# tensor(49.1219, grad_fn=<DivBackward0>)
# tensor(49.0311, grad_fn=<DivBackward0>)
# tensor(48.9405, grad_fn=<DivBackward0>)
# tensor(48.8501, grad_fn=<DivBackward0>)
# tensor(48.7598, grad_fn=<DivBackward0>)
# tensor(48.6697, grad_fn=<DivBackward0>)
# tensor(48.5798, grad_fn=<DivBackward0>)
# tensor(48.4900, grad_fn=<DivBackward0>)
# tensor(48.4004, grad_fn=<DivBackward0>)
# tensor(48.3110, grad_fn=<DivBackward0>)
# tensor(48.2217, grad_fn=<DivBackward0>)
# tensor(48.1326, grad_fn=<DivBackward0>)
# tensor(48.0437, grad_fn=<DivBackward0>)
# tensor(47.9549, grad_fn=<DivBackward0>)
# tensor(47.8663, grad_fn=<DivBackward0>)
# tensor(47.7779, grad_fn=<DivBackward0>)
# tensor(47.6897, grad_fn=<DivBackward0>)
# tensor(47.6016, grad_fn=<DivBackward0>)
# tensor(47.5136, grad_fn=<DivBackward0>)
# tensor(47.4258, grad_fn=<DivBackward0>)
# tensor(47.3383, grad_fn=<DivBackward0>)
# tensor(47.2509, grad_fn=<DivBackward0>)
# tensor(47.1636, grad_fn=<DivBackward0>)
# tensor(47.0765, grad_fn=<DivBackward0>)
# tensor(46.9894, grad_fn=<DivBackward0>)
# tensor(46.9028, grad_fn=<DivBackward0>)
# tensor(46.8161, grad_fn=<DivBackward0>)
# tensor(46.7296, grad_fn=<DivBackward0>)
# tensor(46.6433, grad_fn=<DivBackward0>)
# tensor(46.5572, grad_fn=<DivBackward0>)
# tensor(46.4712, grad_fn=<DivBackward0>)
# tensor(46.3855, grad_fn=<DivBackward0>)
# tensor(46.2998, grad_fn=<DivBackward0>)
# tensor(46.2143, grad_fn=<DivBackward0>)
# tensor(46.1289, grad_fn=<DivBackward0>)
# tensor(46.0437, grad_fn=<DivBackward0>)
# tensor(45.9587, grad_fn=<DivBackward0>)
# tensor(45.8739, grad_fn=<DivBackward0>)
# tensor(45.7892, grad_fn=<DivBackward0>)
# tensor(45.7046, grad_fn=<DivBackward0>)
# tensor(45.6203, grad_fn=<DivBackward0>)
# tensor(45.5361, grad_fn=<DivBackward0>)
# tensor(45.4520, grad_fn=<DivBackward0>)
# tensor(45.3681, grad_fn=<DivBackward0>)
# tensor(45.2844, grad_fn=<DivBackward0>)
# tensor(45.2007, grad_fn=<DivBackward0>)
# tensor(45.1173, grad_fn=<DivBackward0>)
# tensor(45.0340, grad_fn=<DivBackward0>)
# tensor(44.9509, grad_fn=<DivBackward0>)
# tensor(44.8680, grad_fn=<DivBackward0>)
# tensor(44.7852, grad_fn=<DivBackward0>)
# tensor(44.7025, grad_fn=<DivBackward0>)
# tensor(44.6200, grad_fn=<DivBackward0>)
# tensor(44.5376, grad_fn=<DivBackward0>)
# tensor(44.4554, grad_fn=<DivBackward0>)
# tensor(44.3734, grad_fn=<DivBackward0>)
# tensor(44.2915, grad_fn=<DivBackward0>)
# tensor(44.2098, grad_fn=<DivBackward0>)
# tensor(44.1282, grad_fn=<DivBackward0>)
# tensor(44.0468, grad_fn=<DivBackward0>)
# tensor(43.9655, grad_fn=<DivBackward0>)
# tensor(43.8844, grad_fn=<DivBackward0>)
# tensor(43.8034, grad_fn=<DivBackward0>)
# tensor(43.7225, grad_fn=<DivBackward0>)
# tensor(43.6419, grad_fn=<DivBackward0>)
# tensor(43.5614, grad_fn=<DivBackward0>)
# tensor(43.4809, grad_fn=<DivBackward0>)
# tensor(43.4008, grad_fn=<DivBackward0>)
# tensor(43.3207, grad_fn=<DivBackward0>)
# tensor(43.2408, grad_fn=<DivBackward0>)
# tensor(43.1610, grad_fn=<DivBackward0>)
# tensor(43.0814, grad_fn=<DivBackward0>)
# tensor(43.0019, grad_fn=<DivBackward0>)
# tensor(42.9226, grad_fn=<DivBackward0>)
# tensor(42.8434, grad_fn=<DivBackward0>)
# tensor(42.7644, grad_fn=<DivBackward0>)
# tensor(42.6855, grad_fn=<DivBackward0>)
# tensor(42.6068, grad_fn=<DivBackward0>)
# tensor(42.5282, grad_fn=<DivBackward0>)
# tensor(42.4497, grad_fn=<DivBackward0>)
# tensor(42.3715, grad_fn=<DivBackward0>)
# tensor(42.2933, grad_fn=<DivBackward0>)
# tensor(42.2153, grad_fn=<DivBackward0>)
# tensor(42.1375, grad_fn=<DivBackward0>)
# tensor(42.0597, grad_fn=<DivBackward0>)
# tensor(41.9822, grad_fn=<DivBackward0>)
# tensor(41.9047, grad_fn=<DivBackward0>)
# tensor(41.8275, grad_fn=<DivBackward0>)
# tensor(41.7504, grad_fn=<DivBackward0>)
# tensor(41.6734, grad_fn=<DivBackward0>)
# tensor(41.5965, grad_fn=<DivBackward0>)
# tensor(41.5199, grad_fn=<DivBackward0>)
# tensor(41.4433, grad_fn=<DivBackward0>)
# tensor(41.3669, grad_fn=<DivBackward0>)
# tensor(41.2906, grad_fn=<DivBackward0>)
# tensor(41.2145, grad_fn=<DivBackward0>)
# tensor(41.1385, grad_fn=<DivBackward0>)
# tensor(41.0627, grad_fn=<DivBackward0>)
# tensor(40.9869, grad_fn=<DivBackward0>)
# tensor(40.9115, grad_fn=<DivBackward0>)
# tensor(40.8360, grad_fn=<DivBackward0>)
# tensor(40.7607, grad_fn=<DivBackward0>)
# tensor(40.6856, grad_fn=<DivBackward0>)
# tensor(40.6105, grad_fn=<DivBackward0>)
# tensor(40.5357, grad_fn=<DivBackward0>)
# tensor(40.4611, grad_fn=<DivBackward0>)
# tensor(40.3864, grad_fn=<DivBackward0>)
# tensor(40.3120, grad_fn=<DivBackward0>)
# tensor(40.2377, grad_fn=<DivBackward0>)
# tensor(40.1635, grad_fn=<DivBackward0>)
# tensor(40.0895, grad_fn=<DivBackward0>)
# tensor(40.0156, grad_fn=<DivBackward0>)
# tensor(39.9419, grad_fn=<DivBackward0>)
# tensor(39.8683, grad_fn=<DivBackward0>)
# tensor(39.7948, grad_fn=<DivBackward0>)
# tensor(39.7215, grad_fn=<DivBackward0>)
# tensor(39.6483, grad_fn=<DivBackward0>)
# tensor(39.5752, grad_fn=<DivBackward0>)
# tensor(39.5023, grad_fn=<DivBackward0>)
# tensor(39.4295, grad_fn=<DivBackward0>)
# tensor(39.3569, grad_fn=<DivBackward0>)
# tensor(39.2844, grad_fn=<DivBackward0>)
# tensor(39.2120, grad_fn=<DivBackward0>)
# tensor(39.1397, grad_fn=<DivBackward0>)
# tensor(39.0677, grad_fn=<DivBackward0>)
# tensor(38.9957, grad_fn=<DivBackward0>)
# tensor(38.9238, grad_fn=<DivBackward0>)
# tensor(38.8521, grad_fn=<DivBackward0>)
# tensor(38.7806, grad_fn=<DivBackward0>)
# tensor(38.7091, grad_fn=<DivBackward0>)
# tensor(38.6378, grad_fn=<DivBackward0>)
# tensor(38.5667, grad_fn=<DivBackward0>)
# tensor(38.4956, grad_fn=<DivBackward0>)
# tensor(38.4247, grad_fn=<DivBackward0>)
# tensor(38.3539, grad_fn=<DivBackward0>)
# tensor(38.2833, grad_fn=<DivBackward0>)
# tensor(38.2128, grad_fn=<DivBackward0>)
# tensor(38.1424, grad_fn=<DivBackward0>)
# tensor(38.0722, grad_fn=<DivBackward0>)
# tensor(38.0021, grad_fn=<DivBackward0>)
# tensor(37.9321, grad_fn=<DivBackward0>)
# tensor(37.8622, grad_fn=<DivBackward0>)
# tensor(37.7925, grad_fn=<DivBackward0>)
# tensor(37.7229, grad_fn=<DivBackward0>)
# tensor(37.6535, grad_fn=<DivBackward0>)
# tensor(37.5841, grad_fn=<DivBackward0>)
# tensor(37.5149, grad_fn=<DivBackward0>)
# tensor(37.4459, grad_fn=<DivBackward0>)
# tensor(37.3769, grad_fn=<DivBackward0>)
# tensor(37.3081, grad_fn=<DivBackward0>)
# tensor(37.2394, grad_fn=<DivBackward0>)
# tensor(37.1709, grad_fn=<DivBackward0>)
# tensor(37.1024, grad_fn=<DivBackward0>)
# tensor(37.0341, grad_fn=<DivBackward0>)
# tensor(36.9660, grad_fn=<DivBackward0>)
# tensor(36.8979, grad_fn=<DivBackward0>)
# tensor(36.8301, grad_fn=<DivBackward0>)
# tensor(36.7622, grad_fn=<DivBackward0>)
# tensor(36.6945, grad_fn=<DivBackward0>)
# tensor(36.6270, grad_fn=<DivBackward0>)
# tensor(36.5596, grad_fn=<DivBackward0>)
# tensor(36.4923, grad_fn=<DivBackward0>)
# tensor(36.4251, grad_fn=<DivBackward0>)
# tensor(36.3581, grad_fn=<DivBackward0>)
# tensor(36.2912, grad_fn=<DivBackward0>)
# tensor(36.2244, grad_fn=<DivBackward0>)
# tensor(36.1578, grad_fn=<DivBackward0>)
# tensor(36.0912, grad_fn=<DivBackward0>)
# tensor(36.0248, grad_fn=<DivBackward0>)
# tensor(35.9585, grad_fn=<DivBackward0>)
# tensor(35.8923, grad_fn=<DivBackward0>)
# tensor(35.8263, grad_fn=<DivBackward0>)
# tensor(35.7604, grad_fn=<DivBackward0>)
# tensor(35.6946, grad_fn=<DivBackward0>)
# tensor(35.6289, grad_fn=<DivBackward0>)
# tensor(35.5633, grad_fn=<DivBackward0>)
# tensor(35.4979, grad_fn=<DivBackward0>)
# tensor(35.4326, grad_fn=<DivBackward0>)
# tensor(35.3675, grad_fn=<DivBackward0>)
# tensor(35.3024, grad_fn=<DivBackward0>)
# tensor(35.2375, grad_fn=<DivBackward0>)
# tensor(35.1727, grad_fn=<DivBackward0>)
# tensor(35.1079, grad_fn=<DivBackward0>)
# tensor(35.0434, grad_fn=<DivBackward0>)
# tensor(34.9789, grad_fn=<DivBackward0>)
# tensor(34.9146, grad_fn=<DivBackward0>)
# tensor(34.8504, grad_fn=<DivBackward0>)
# tensor(34.7863, grad_fn=<DivBackward0>)
# tensor(34.7223, grad_fn=<DivBackward0>)
# tensor(34.6584, grad_fn=<DivBackward0>)
# tensor(34.5947, grad_fn=<DivBackward0>)
# tensor(34.5310, grad_fn=<DivBackward0>)
# tensor(34.4676, grad_fn=<DivBackward0>)
# tensor(34.4042, grad_fn=<DivBackward0>)
# tensor(34.3409, grad_fn=<DivBackward0>)
# tensor(34.2778, grad_fn=<DivBackward0>)
# tensor(34.2148, grad_fn=<DivBackward0>)
# tensor(34.1519, grad_fn=<DivBackward0>)
# tensor(34.0890, grad_fn=<DivBackward0>)
# tensor(34.0264, grad_fn=<DivBackward0>)
# tensor(33.9638, grad_fn=<DivBackward0>)
# tensor(33.9014, grad_fn=<DivBackward0>)
# tensor(33.8391, grad_fn=<DivBackward0>)
# tensor(33.7769, grad_fn=<DivBackward0>)
# tensor(33.7148, grad_fn=<DivBackward0>)
# tensor(33.6528, grad_fn=<DivBackward0>)
# tensor(33.5909, grad_fn=<DivBackward0>)
# tensor(33.5292, grad_fn=<DivBackward0>)
# tensor(33.4676, grad_fn=<DivBackward0>)
# tensor(33.4060, grad_fn=<DivBackward0>)
# tensor(33.3446, grad_fn=<DivBackward0>)
# tensor(33.2834, grad_fn=<DivBackward0>)
# tensor(33.2222, grad_fn=<DivBackward0>)
# tensor(33.1612, grad_fn=<DivBackward0>)
# tensor(33.1002, grad_fn=<DivBackward0>)
# tensor(33.0393, grad_fn=<DivBackward0>)
# tensor(32.9786, grad_fn=<DivBackward0>)
# tensor(32.9181, grad_fn=<DivBackward0>)
# tensor(32.8575, grad_fn=<DivBackward0>)
# tensor(32.7972, grad_fn=<DivBackward0>)
# tensor(32.7369, grad_fn=<DivBackward0>)
# tensor(32.6768, grad_fn=<DivBackward0>)
# tensor(32.6168, grad_fn=<DivBackward0>)
# tensor(32.5568, grad_fn=<DivBackward0>)
# tensor(32.4970, grad_fn=<DivBackward0>)
# tensor(32.4373, grad_fn=<DivBackward0>)
# tensor(32.3777, grad_fn=<DivBackward0>)
# tensor(32.3182, grad_fn=<DivBackward0>)
# tensor(32.2588, grad_fn=<DivBackward0>)
# tensor(32.1996, grad_fn=<DivBackward0>)
# tensor(32.1404, grad_fn=<DivBackward0>)
# tensor(32.0814, grad_fn=<DivBackward0>)
# tensor(32.0225, grad_fn=<DivBackward0>)
# tensor(31.9636, grad_fn=<DivBackward0>)
# tensor(31.9050, grad_fn=<DivBackward0>)
# tensor(31.8464, grad_fn=<DivBackward0>)
# tensor(31.7879, grad_fn=<DivBackward0>)
# tensor(31.7295, grad_fn=<DivBackward0>)
# tensor(31.6712, grad_fn=<DivBackward0>)
# tensor(31.6131, grad_fn=<DivBackward0>)
# tensor(31.5550, grad_fn=<DivBackward0>)
# tensor(31.4971, grad_fn=<DivBackward0>)
# tensor(31.4392, grad_fn=<DivBackward0>)
# tensor(31.3815, grad_fn=<DivBackward0>)
# tensor(31.3239, grad_fn=<DivBackward0>)
# tensor(31.2664, grad_fn=<DivBackward0>)
# tensor(31.2090, grad_fn=<DivBackward0>)
# tensor(31.1517, grad_fn=<DivBackward0>)
# tensor(31.0945, grad_fn=<DivBackward0>)
# tensor(31.0374, grad_fn=<DivBackward0>)
# tensor(30.9804, grad_fn=<DivBackward0>)
# tensor(30.9236, grad_fn=<DivBackward0>)
# tensor(30.8668, grad_fn=<DivBackward0>)
# tensor(30.8101, grad_fn=<DivBackward0>)
# tensor(30.7536, grad_fn=<DivBackward0>)
# tensor(30.6971, grad_fn=<DivBackward0>)
# tensor(30.6408, grad_fn=<DivBackward0>)
# tensor(30.5846, grad_fn=<DivBackward0>)
# tensor(30.5285, grad_fn=<DivBackward0>)
# tensor(30.4724, grad_fn=<DivBackward0>)
# tensor(30.4165, grad_fn=<DivBackward0>)
# tensor(30.3606, grad_fn=<DivBackward0>)
# tensor(30.3049, grad_fn=<DivBackward0>)
# tensor(30.2493, grad_fn=<DivBackward0>)
# tensor(30.1938, grad_fn=<DivBackward0>)
# tensor(30.1384, grad_fn=<DivBackward0>)
# tensor(30.0831, grad_fn=<DivBackward0>)
# tensor(30.0279, grad_fn=<DivBackward0>)
# tensor(29.9728, grad_fn=<DivBackward0>)
# tensor(29.9179, grad_fn=<DivBackward0>)
# tensor(29.8630, grad_fn=<DivBackward0>)
# tensor(29.8081, grad_fn=<DivBackward0>)
# tensor(29.7535, grad_fn=<DivBackward0>)
# tensor(29.6989, grad_fn=<DivBackward0>)
# tensor(29.6444, grad_fn=<DivBackward0>)
# tensor(29.5901, grad_fn=<DivBackward0>)
# tensor(29.5358, grad_fn=<DivBackward0>)
# tensor(29.4816, grad_fn=<DivBackward0>)
# tensor(29.4275, grad_fn=<DivBackward0>)
# tensor(29.3735, grad_fn=<DivBackward0>)
# tensor(29.3196, grad_fn=<DivBackward0>)
# tensor(29.2659, grad_fn=<DivBackward0>)
# tensor(29.2122, grad_fn=<DivBackward0>)
# tensor(29.1587, grad_fn=<DivBackward0>)
# tensor(29.1052, grad_fn=<DivBackward0>)
# tensor(29.0518, grad_fn=<DivBackward0>)
# tensor(28.9985, grad_fn=<DivBackward0>)
# tensor(28.9454, grad_fn=<DivBackward0>)
# tensor(28.8923, grad_fn=<DivBackward0>)
# tensor(28.8393, grad_fn=<DivBackward0>)
# tensor(28.7864, grad_fn=<DivBackward0>)
# tensor(28.7336, grad_fn=<DivBackward0>)
# tensor(28.6810, grad_fn=<DivBackward0>)
# tensor(28.6284, grad_fn=<DivBackward0>)
# tensor(28.5759, grad_fn=<DivBackward0>)
# tensor(28.5235, grad_fn=<DivBackward0>)
# tensor(28.4712, grad_fn=<DivBackward0>)
# tensor(28.4190, grad_fn=<DivBackward0>)
# tensor(28.3670, grad_fn=<DivBackward0>)
# tensor(28.3150, grad_fn=<DivBackward0>)
# tensor(28.2631, grad_fn=<DivBackward0>)
# tensor(28.2113, grad_fn=<DivBackward0>)
# tensor(28.1596, grad_fn=<DivBackward0>)
# tensor(28.1080, grad_fn=<DivBackward0>)
# tensor(28.0565, grad_fn=<DivBackward0>)
# tensor(28.0051, grad_fn=<DivBackward0>)
# tensor(27.9537, grad_fn=<DivBackward0>)
# tensor(27.9025, grad_fn=<DivBackward0>)
# tensor(27.8514, grad_fn=<DivBackward0>)
# tensor(27.8003, grad_fn=<DivBackward0>)
# tensor(27.7494, grad_fn=<DivBackward0>)
# tensor(27.6986, grad_fn=<DivBackward0>)
# tensor(27.6478, grad_fn=<DivBackward0>)
# tensor(27.5972, grad_fn=<DivBackward0>)
# tensor(27.5466, grad_fn=<DivBackward0>)
# tensor(27.4962, grad_fn=<DivBackward0>)
# tensor(27.4458, grad_fn=<DivBackward0>)
# tensor(27.3955, grad_fn=<DivBackward0>)
# tensor(27.3454, grad_fn=<DivBackward0>)
# tensor(27.2952, grad_fn=<DivBackward0>)
# tensor(27.2453, grad_fn=<DivBackward0>)
# tensor(27.1954, grad_fn=<DivBackward0>)
# tensor(27.1456, grad_fn=<DivBackward0>)
# tensor(27.0958, grad_fn=<DivBackward0>)
# tensor(27.0462, grad_fn=<DivBackward0>)
# tensor(26.9967, grad_fn=<DivBackward0>)
# tensor(26.9473, grad_fn=<DivBackward0>)
# tensor(26.8979, grad_fn=<DivBackward0>)
# tensor(26.8487, grad_fn=<DivBackward0>)
# tensor(26.7995, grad_fn=<DivBackward0>)
# tensor(26.7505, grad_fn=<DivBackward0>)
# tensor(26.7015, grad_fn=<DivBackward0>)
# tensor(26.6526, grad_fn=<DivBackward0>)
# tensor(26.6038, grad_fn=<DivBackward0>)
# tensor(26.5551, grad_fn=<DivBackward0>)
# tensor(26.5065, grad_fn=<DivBackward0>)
# tensor(26.4580, grad_fn=<DivBackward0>)
# tensor(26.4095, grad_fn=<DivBackward0>)
# tensor(26.3612, grad_fn=<DivBackward0>)
# tensor(26.3129, grad_fn=<DivBackward0>)
# tensor(26.2647, grad_fn=<DivBackward0>)
# tensor(26.2167, grad_fn=<DivBackward0>)
# tensor(26.1687, grad_fn=<DivBackward0>)
# tensor(26.1208, grad_fn=<DivBackward0>)
# tensor(26.0730, grad_fn=<DivBackward0>)
# tensor(26.0253, grad_fn=<DivBackward0>)
# tensor(25.9777, grad_fn=<DivBackward0>)
# tensor(25.9301, grad_fn=<DivBackward0>)
# tensor(25.8827, grad_fn=<DivBackward0>)
# tensor(25.8353, grad_fn=<DivBackward0>)
# tensor(25.7881, grad_fn=<DivBackward0>)
# tensor(25.7409, grad_fn=<DivBackward0>)
# tensor(25.6938, grad_fn=<DivBackward0>)
# tensor(25.6468, grad_fn=<DivBackward0>)
# tensor(25.5999, grad_fn=<DivBackward0>)
# tensor(25.5531, grad_fn=<DivBackward0>)
# tensor(25.5063, grad_fn=<DivBackward0>)
# tensor(25.4597, grad_fn=<DivBackward0>)
# tensor(25.4131, grad_fn=<DivBackward0>)
# tensor(25.3666, grad_fn=<DivBackward0>)
# tensor(25.3202, grad_fn=<DivBackward0>)
# tensor(25.2739, grad_fn=<DivBackward0>)
# tensor(25.2277, grad_fn=<DivBackward0>)
# tensor(25.1816, grad_fn=<DivBackward0>)
# tensor(25.1355, grad_fn=<DivBackward0>)
# tensor(25.0896, grad_fn=<DivBackward0>)
# tensor(25.0437, grad_fn=<DivBackward0>)
# tensor(24.9979, grad_fn=<DivBackward0>)
# tensor(24.9522, grad_fn=<DivBackward0>)
# tensor(24.9065, grad_fn=<DivBackward0>)
# tensor(24.8610, grad_fn=<DivBackward0>)
# tensor(24.8156, grad_fn=<DivBackward0>)
# tensor(24.7702, grad_fn=<DivBackward0>)
# tensor(24.7249, grad_fn=<DivBackward0>)
# tensor(24.6797, grad_fn=<DivBackward0>)
# tensor(24.6346, grad_fn=<DivBackward0>)
# tensor(24.5896, grad_fn=<DivBackward0>)
# tensor(24.5447, grad_fn=<DivBackward0>)
# tensor(24.4998, grad_fn=<DivBackward0>)
# tensor(24.4550, grad_fn=<DivBackward0>)
# tensor(24.4103, grad_fn=<DivBackward0>)
# tensor(24.3657, grad_fn=<DivBackward0>)
# tensor(24.3211, grad_fn=<DivBackward0>)
# tensor(24.2768, grad_fn=<DivBackward0>)
# tensor(24.2324, grad_fn=<DivBackward0>)
# tensor(24.1880, grad_fn=<DivBackward0>)
# tensor(24.1439, grad_fn=<DivBackward0>)
# tensor(24.0998, grad_fn=<DivBackward0>)
# tensor(24.0558, grad_fn=<DivBackward0>)
# tensor(24.0118, grad_fn=<DivBackward0>)
# tensor(23.9679, grad_fn=<DivBackward0>)
# tensor(23.9242, grad_fn=<DivBackward0>)
# tensor(23.8805, grad_fn=<DivBackward0>)
# tensor(23.8368, grad_fn=<DivBackward0>)
# tensor(23.7933, grad_fn=<DivBackward0>)
# tensor(23.7499, grad_fn=<DivBackward0>)
# tensor(23.7064, grad_fn=<DivBackward0>)
# tensor(23.6632, grad_fn=<DivBackward0>)
# tensor(23.6200, grad_fn=<DivBackward0>)
# tensor(23.5768, grad_fn=<DivBackward0>)
# tensor(23.5338, grad_fn=<DivBackward0>)
# tensor(23.4908, grad_fn=<DivBackward0>)
# tensor(23.4479, grad_fn=<DivBackward0>)
# tensor(23.4050, grad_fn=<DivBackward0>)
# tensor(23.3624, grad_fn=<DivBackward0>)
# tensor(23.3197, grad_fn=<DivBackward0>)
# tensor(23.2771, grad_fn=<DivBackward0>)
# tensor(23.2346, grad_fn=<DivBackward0>)
# tensor(23.1922, grad_fn=<DivBackward0>)
# tensor(23.1499, grad_fn=<DivBackward0>)
# tensor(23.1076, grad_fn=<DivBackward0>)
# tensor(23.0654, grad_fn=<DivBackward0>)
# tensor(23.0234, grad_fn=<DivBackward0>)
# tensor(22.9813, grad_fn=<DivBackward0>)
# tensor(22.9394, grad_fn=<DivBackward0>)
# tensor(22.8975, grad_fn=<DivBackward0>)
# tensor(22.8557, grad_fn=<DivBackward0>)
# tensor(22.8140, grad_fn=<DivBackward0>)
# tensor(22.7724, grad_fn=<DivBackward0>)
# tensor(22.7308, grad_fn=<DivBackward0>)
# tensor(22.6893, grad_fn=<DivBackward0>)
# tensor(22.6480, grad_fn=<DivBackward0>)
# tensor(22.6067, grad_fn=<DivBackward0>)
# tensor(22.5654, grad_fn=<DivBackward0>)
# tensor(22.5242, grad_fn=<DivBackward0>)
# tensor(22.4831, grad_fn=<DivBackward0>)
# tensor(22.4421, grad_fn=<DivBackward0>)
# tensor(22.4012, grad_fn=<DivBackward0>)
# tensor(22.3603, grad_fn=<DivBackward0>)
# tensor(22.3195, grad_fn=<DivBackward0>)
# tensor(22.2788, grad_fn=<DivBackward0>)
# tensor(22.2382, grad_fn=<DivBackward0>)
# tensor(22.1977, grad_fn=<DivBackward0>)
# tensor(22.1571, grad_fn=<DivBackward0>)
# tensor(22.1167, grad_fn=<DivBackward0>)
# tensor(22.0764, grad_fn=<DivBackward0>)
# tensor(22.0362, grad_fn=<DivBackward0>)
# tensor(21.9960, grad_fn=<DivBackward0>)
# tensor(21.9559, grad_fn=<DivBackward0>)
# tensor(21.9159, grad_fn=<DivBackward0>)
# tensor(21.8759, grad_fn=<DivBackward0>)
# tensor(21.8360, grad_fn=<DivBackward0>)
# tensor(21.7963, grad_fn=<DivBackward0>)
# tensor(21.7565, grad_fn=<DivBackward0>)
# tensor(21.7168, grad_fn=<DivBackward0>)
# tensor(21.6773, grad_fn=<DivBackward0>)
# tensor(21.6378, grad_fn=<DivBackward0>)
# tensor(21.5983, grad_fn=<DivBackward0>)
# tensor(21.5590, grad_fn=<DivBackward0>)
# tensor(21.5197, grad_fn=<DivBackward0>)
# tensor(21.4804, grad_fn=<DivBackward0>)
# tensor(21.4413, grad_fn=<DivBackward0>)
# tensor(21.4023, grad_fn=<DivBackward0>)
# tensor(21.3633, grad_fn=<DivBackward0>)
# tensor(21.3243, grad_fn=<DivBackward0>)
# tensor(21.2855, grad_fn=<DivBackward0>)
# tensor(21.2467, grad_fn=<DivBackward0>)
# tensor(21.2080, grad_fn=<DivBackward0>)
# tensor(21.1694, grad_fn=<DivBackward0>)
# tensor(21.1308, grad_fn=<DivBackward0>)
# tensor(21.0923, grad_fn=<DivBackward0>)
# tensor(21.0539, grad_fn=<DivBackward0>)
# tensor(21.0155, grad_fn=<DivBackward0>)
# tensor(20.9773, grad_fn=<DivBackward0>)
# tensor(20.9390, grad_fn=<DivBackward0>)
# tensor(20.9009, grad_fn=<DivBackward0>)
# tensor(20.8629, grad_fn=<DivBackward0>)
# tensor(20.8249, grad_fn=<DivBackward0>)
# tensor(20.7870, grad_fn=<DivBackward0>)
# tensor(20.7491, grad_fn=<DivBackward0>)
# tensor(20.7114, grad_fn=<DivBackward0>)
# tensor(20.6737, grad_fn=<DivBackward0>)
# tensor(20.6360, grad_fn=<DivBackward0>)
# tensor(20.5984, grad_fn=<DivBackward0>)
# tensor(20.5609, grad_fn=<DivBackward0>)
# tensor(20.5235, grad_fn=<DivBackward0>)
# tensor(20.4861, grad_fn=<DivBackward0>)
# tensor(20.4489, grad_fn=<DivBackward0>)
# tensor(20.4116, grad_fn=<DivBackward0>)
# tensor(20.3745, grad_fn=<DivBackward0>)
# tensor(20.3374, grad_fn=<DivBackward0>)
# tensor(20.3004, grad_fn=<DivBackward0>)
# tensor(20.2635, grad_fn=<DivBackward0>)
# tensor(20.2266, grad_fn=<DivBackward0>)
# tensor(20.1898, grad_fn=<DivBackward0>)
# tensor(20.1530, grad_fn=<DivBackward0>)
# tensor(20.1164, grad_fn=<DivBackward0>)
# tensor(20.0798, grad_fn=<DivBackward0>)
# tensor(20.0433, grad_fn=<DivBackward0>)
# tensor(20.0068, grad_fn=<DivBackward0>)
# tensor(19.9705, grad_fn=<DivBackward0>)
# tensor(19.9341, grad_fn=<DivBackward0>)
# tensor(19.8979, grad_fn=<DivBackward0>)
# tensor(19.8617, grad_fn=<DivBackward0>)
# tensor(19.8256, grad_fn=<DivBackward0>)
# tensor(19.7895, grad_fn=<DivBackward0>)
# tensor(19.7535, grad_fn=<DivBackward0>)
# tensor(19.7176, grad_fn=<DivBackward0>)
# tensor(19.6817, grad_fn=<DivBackward0>)
# tensor(19.6459, grad_fn=<DivBackward0>)
# tensor(19.6102, grad_fn=<DivBackward0>)
# tensor(19.5746, grad_fn=<DivBackward0>)
# tensor(19.5390, grad_fn=<DivBackward0>)
# tensor(19.5034, grad_fn=<DivBackward0>)
# tensor(19.4680, grad_fn=<DivBackward0>)
# tensor(19.4326, grad_fn=<DivBackward0>)
# tensor(19.3973, grad_fn=<DivBackward0>)
# tensor(19.3620, grad_fn=<DivBackward0>)
# tensor(19.3269, grad_fn=<DivBackward0>)
# tensor(19.2917, grad_fn=<DivBackward0>)
# tensor(19.2567, grad_fn=<DivBackward0>)
# tensor(19.2217, grad_fn=<DivBackward0>)
# tensor(19.1868, grad_fn=<DivBackward0>)
# tensor(19.1519, grad_fn=<DivBackward0>)
# tensor(19.1171, grad_fn=<DivBackward0>)
# tensor(19.0824, grad_fn=<DivBackward0>)
# tensor(19.0477, grad_fn=<DivBackward0>)
# tensor(19.0131, grad_fn=<DivBackward0>)
# tensor(18.9786, grad_fn=<DivBackward0>)
# tensor(18.9441, grad_fn=<DivBackward0>)
# tensor(18.9097, grad_fn=<DivBackward0>)
# tensor(18.8754, grad_fn=<DivBackward0>)
# tensor(18.8411, grad_fn=<DivBackward0>)
# tensor(18.8069, grad_fn=<DivBackward0>)
# tensor(18.7727, grad_fn=<DivBackward0>)
# tensor(18.7386, grad_fn=<DivBackward0>)
# tensor(18.7046, grad_fn=<DivBackward0>)
# tensor(18.6706, grad_fn=<DivBackward0>)
# tensor(18.6367, grad_fn=<DivBackward0>)
# tensor(18.6029, grad_fn=<DivBackward0>)
# tensor(18.5691, grad_fn=<DivBackward0>)
# tensor(18.5354, grad_fn=<DivBackward0>)
# tensor(18.5018, grad_fn=<DivBackward0>)
# tensor(18.4682, grad_fn=<DivBackward0>)
# tensor(18.4347, grad_fn=<DivBackward0>)
# tensor(18.4012, grad_fn=<DivBackward0>)
# tensor(18.3678, grad_fn=<DivBackward0>)
# tensor(18.3345, grad_fn=<DivBackward0>)
# tensor(18.3012, grad_fn=<DivBackward0>)
# tensor(18.2680, grad_fn=<DivBackward0>)
# tensor(18.2349, grad_fn=<DivBackward0>)
# tensor(18.2018, grad_fn=<DivBackward0>)
# tensor(18.1687, grad_fn=<DivBackward0>)
# tensor(18.1358, grad_fn=<DivBackward0>)
# tensor(18.1029, grad_fn=<DivBackward0>)
# tensor(18.0700, grad_fn=<DivBackward0>)
# tensor(18.0373, grad_fn=<DivBackward0>)
# tensor(18.0046, grad_fn=<DivBackward0>)
# tensor(17.9719, grad_fn=<DivBackward0>)
# tensor(17.9393, grad_fn=<DivBackward0>)
# tensor(17.9068, grad_fn=<DivBackward0>)
# tensor(17.8743, grad_fn=<DivBackward0>)
# tensor(17.8419, grad_fn=<DivBackward0>)
# tensor(17.8095, grad_fn=<DivBackward0>)
# tensor(17.7773, grad_fn=<DivBackward0>)
# tensor(17.7450, grad_fn=<DivBackward0>)
# tensor(17.7128, grad_fn=<DivBackward0>)
# tensor(17.6807, grad_fn=<DivBackward0>)
# tensor(17.6487, grad_fn=<DivBackward0>)
# tensor(17.6167, grad_fn=<DivBackward0>)
# tensor(17.5847, grad_fn=<DivBackward0>)
# tensor(17.5529, grad_fn=<DivBackward0>)
# tensor(17.5210, grad_fn=<DivBackward0>)
# tensor(17.4893, grad_fn=<DivBackward0>)
# tensor(17.4576, grad_fn=<DivBackward0>)
# tensor(17.4260, grad_fn=<DivBackward0>)
# tensor(17.3944, grad_fn=<DivBackward0>)
# tensor(17.3629, grad_fn=<DivBackward0>)
# tensor(17.3314, grad_fn=<DivBackward0>)
# tensor(17.3000, grad_fn=<DivBackward0>)
# tensor(17.2687, grad_fn=<DivBackward0>)
# tensor(17.2374, grad_fn=<DivBackward0>)
# tensor(17.2062, grad_fn=<DivBackward0>)
# tensor(17.1750, grad_fn=<DivBackward0>)
# tensor(17.1439, grad_fn=<DivBackward0>)
# tensor(17.1128, grad_fn=<DivBackward0>)
# tensor(17.0819, grad_fn=<DivBackward0>)
# tensor(17.0509, grad_fn=<DivBackward0>)
# tensor(17.0201, grad_fn=<DivBackward0>)
# tensor(16.9892, grad_fn=<DivBackward0>)
# tensor(16.9585, grad_fn=<DivBackward0>)
# tensor(16.9278, grad_fn=<DivBackward0>)
# tensor(16.8971, grad_fn=<DivBackward0>)
# tensor(16.8666, grad_fn=<DivBackward0>)
# tensor(16.8360, grad_fn=<DivBackward0>)
# tensor(16.8055, grad_fn=<DivBackward0>)
# tensor(16.7751, grad_fn=<DivBackward0>)
# tensor(16.7447, grad_fn=<DivBackward0>)
# tensor(16.7145, grad_fn=<DivBackward0>)
# tensor(16.6842, grad_fn=<DivBackward0>)
# tensor(16.6540, grad_fn=<DivBackward0>)
# tensor(16.6239, grad_fn=<DivBackward0>)
# tensor(16.5938, grad_fn=<DivBackward0>)
# tensor(16.5638, grad_fn=<DivBackward0>)
# tensor(16.5338, grad_fn=<DivBackward0>)
# tensor(16.5039, grad_fn=<DivBackward0>)
# tensor(16.4740, grad_fn=<DivBackward0>)
# tensor(16.4443, grad_fn=<DivBackward0>)
# tensor(16.4145, grad_fn=<DivBackward0>)
# tensor(16.3848, grad_fn=<DivBackward0>)
# tensor(16.3552, grad_fn=<DivBackward0>)
# tensor(16.3256, grad_fn=<DivBackward0>)
# tensor(16.2961, grad_fn=<DivBackward0>)
# tensor(16.2666, grad_fn=<DivBackward0>)
# tensor(16.2372, grad_fn=<DivBackward0>)
# tensor(16.2079, grad_fn=<DivBackward0>)
# tensor(16.1786, grad_fn=<DivBackward0>)
# tensor(16.1493, grad_fn=<DivBackward0>)
# tensor(16.1201, grad_fn=<DivBackward0>)
# tensor(16.0910, grad_fn=<DivBackward0>)
# tensor(16.0619, grad_fn=<DivBackward0>)
# tensor(16.0328, grad_fn=<DivBackward0>)
# tensor(16.0039, grad_fn=<DivBackward0>)
# tensor(15.9749, grad_fn=<DivBackward0>)
# tensor(15.9461, grad_fn=<DivBackward0>)
# tensor(15.9173, grad_fn=<DivBackward0>)
# tensor(15.8885, grad_fn=<DivBackward0>)
# tensor(15.8598, grad_fn=<DivBackward0>)
# tensor(15.8312, grad_fn=<DivBackward0>)
# tensor(15.8025, grad_fn=<DivBackward0>)
# tensor(15.7740, grad_fn=<DivBackward0>)
# tensor(15.7455, grad_fn=<DivBackward0>)
# tensor(15.7171, grad_fn=<DivBackward0>)
# tensor(15.6887, grad_fn=<DivBackward0>)
# tensor(15.6604, grad_fn=<DivBackward0>)
# tensor(15.6321, grad_fn=<DivBackward0>)
# tensor(15.6038, grad_fn=<DivBackward0>)
# tensor(15.5757, grad_fn=<DivBackward0>)
# tensor(15.5475, grad_fn=<DivBackward0>)
# tensor(15.5195, grad_fn=<DivBackward0>)
# tensor(15.4914, grad_fn=<DivBackward0>)
# tensor(15.4635, grad_fn=<DivBackward0>)
# tensor(15.4356, grad_fn=<DivBackward0>)
# tensor(15.4077, grad_fn=<DivBackward0>)
# tensor(15.3799, grad_fn=<DivBackward0>)
# tensor(15.3522, grad_fn=<DivBackward0>)
# tensor(15.3244, grad_fn=<DivBackward0>)
# tensor(15.2968, grad_fn=<DivBackward0>)
# tensor(15.2692, grad_fn=<DivBackward0>)
# tensor(15.2416, grad_fn=<DivBackward0>)
# tensor(15.2141, grad_fn=<DivBackward0>)
# tensor(15.1867, grad_fn=<DivBackward0>)
# tensor(15.1593, grad_fn=<DivBackward0>)
# tensor(15.1319, grad_fn=<DivBackward0>)
# tensor(15.1046, grad_fn=<DivBackward0>)
# tensor(15.0774, grad_fn=<DivBackward0>)
# tensor(15.0502, grad_fn=<DivBackward0>)
# tensor(15.0231, grad_fn=<DivBackward0>)
# tensor(14.9960, grad_fn=<DivBackward0>)
# tensor(14.9689, grad_fn=<DivBackward0>)
# tensor(14.9419, grad_fn=<DivBackward0>)
# tensor(14.9150, grad_fn=<DivBackward0>)
# tensor(14.8881, grad_fn=<DivBackward0>)
# tensor(14.8613, grad_fn=<DivBackward0>)
# tensor(14.8345, grad_fn=<DivBackward0>)
# tensor(14.8077, grad_fn=<DivBackward0>)
# tensor(14.7810, grad_fn=<DivBackward0>)
# tensor(14.7544, grad_fn=<DivBackward0>)
# tensor(14.7278, grad_fn=<DivBackward0>)
# tensor(14.7013, grad_fn=<DivBackward0>)
# tensor(14.6748, grad_fn=<DivBackward0>)
# tensor(14.6483, grad_fn=<DivBackward0>)
# tensor(14.6220, grad_fn=<DivBackward0>)
# tensor(14.5956, grad_fn=<DivBackward0>)
# tensor(14.5693, grad_fn=<DivBackward0>)
# tensor(14.5431, grad_fn=<DivBackward0>)
# tensor(14.5169, grad_fn=<DivBackward0>)
# tensor(14.4907, grad_fn=<DivBackward0>)
# tensor(14.4646, grad_fn=<DivBackward0>)
# tensor(14.4386, grad_fn=<DivBackward0>)
# tensor(14.4126, grad_fn=<DivBackward0>)
# tensor(14.3866, grad_fn=<DivBackward0>)
# tensor(14.3607, grad_fn=<DivBackward0>)

# %% [markdown]
# Once again, let's verify that the loss is now lower:

# %%
# Calculate loss
preds = model(inputs)
loss = mse(preds, targets)
print(loss)
# Out:
# tensor(14.3349, grad_fn=<DivBackward0>)

# %% [markdown]
# The loss is now much lower than its initial value. Let's look at the model's predictions and compare them with the targets.

# %%
# Predictions
preds
# Out:
# tensor([[ 56.8610,  70.5966],
#         [ 84.4695,  97.7465],
#         [114.0355, 139.1444],
#         [ 19.7827,  38.7544],
#         [106.5698, 112.9592]], grad_fn=<AddBackward0>)

# %%
# Targets
targets
# Out:
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])

# %% [markdown]
# The predictions are now quite close to the target variables. We can get even better results by training for a few more epochs.

# %% [markdown]
# ## Linear regression using PyTorch built-ins
#
# We've implemented linear regression & gradient descent model using some basic tensor operations. However, since this is a common pattern in deep learning, PyTorch provides several built-in functions and classes to make it easy to create and train models with just a few lines of code.
#
# Let's begin by importing the `torch.nn` package from PyTorch, which contains utility classes for building neural networks.

# %%
import torch.nn as nn

# %% [markdown]
# As before, we represent the inputs and targets and matrices.

# %%
# Input (temp, rainfall, humidity)
inputs = np.array([[73, 67, 43], 
                   [91, 88, 64], 
                   [87, 134, 58], 
                   [102, 43, 37], 
                   [69, 96, 70], 
                   [74, 66, 43], 
                   [91, 87, 65], 
                   [88, 134, 59], 
                   [101, 44, 37], 
                   [68, 96, 71], 
                   [73, 66, 44], 
                   [92, 87, 64], 
                   [87, 135, 57], 
                   [103, 43, 36], 
                   [68, 97, 70]], 
                  dtype='float32')
 
# Targets (apples, oranges)
targets = np.array([[56, 70], 
                    [81, 101], 
                    [119, 133], 
                    [22, 37], 
                    [103, 119],
                    [57, 69], 
                    [80, 102], 
                    [118, 132], 
                    [21, 38], 
                    [104, 118], 
                    [57, 69], 
                    [82, 100], 
                    [118, 134], 
                    [20, 38], 
                    [102, 120]], 
                   dtype='float32')
 
inputs = torch.from_numpy(inputs)
targets = torch.from_numpy(targets)

# %%
inputs
# Out:
# tensor([[ 73.,  67.,  43.],
#         [ 91.,  88.,  64.],
#         [ 87., 134.,  58.],
#         [102.,  43.,  37.],
#         [ 69.,  96.,  70.],
#         [ 74.,  66.,  43.],
#         [ 91.,  87.,  65.],
#         [ 88., 134.,  59.],
#         [101.,  44.,  37.],
#         [ 68.,  96.,  71.],
#         [ 73.,  66.,  44.],
#         [ 92.,  87.,  64.],
#         [ 87., 135.,  57.],
#         [103.,  43.,  36.],
#         [ 68.,  97.,  70.]])

# %% [markdown]
# We are using 15 training examples to illustrate how to work with large datasets in small batches.

# %% [markdown]
# ## Dataset and DataLoader
#
# We'll create a `TensorDataset`, which allows access to rows from `inputs` and `targets` as tuples, and provides standard APIs for working with many different types of datasets in PyTorch.

# %%
from torch.utils.data import TensorDataset

# %%
TensorDataset?

# %%
# Define dataset
train_ds = TensorDataset(inputs, targets)
train_ds[:3]
# Out:
# (tensor([[ 73.,  67.,  43.],
#          [ 91.,  88.,  64.],
#          [ 87., 134.,  58.]]), tensor([[ 56.,  70.],
#          [ 81., 101.],
#          [119., 133.]]))

# %%
train_ds[0:3]
# Out:
# (tensor([[ 73.,  67.,  43.],
#          [ 91.,  88.,  64.],
#          [ 87., 134.,  58.]]), tensor([[ 56.,  70.],
#          [ 81., 101.],
#          [119., 133.]]))

# %% [markdown]
# The `TensorDataset` allows us to access a small section of the training data using the array indexing notation (`[0:3]` in the above code). It returns a tuple with two elements. The first element contains the input variables for the selected rows, and the second contains the targets.

# %% [markdown]
# We'll also create a `DataLoader`, which can split the data into batches of a predefined size while training. It also provides other utilities like shuffling and random sampling of the data.

# %%
from torch.utils.data import DataLoader

# %%
DataLoader?

# %%
# Define data loader
batch_size = 5
train_dl = DataLoader(train_ds, batch_size, shuffle=True)

# %%
print(train_dl)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7fc1e6092850>

# %% [markdown]
# We can use the data loader in a `for` loop. Let's look at an example.

# %%
for xb, yb in train_dl:
    print(xb)
    print(yb)
    # break
# Out:
# tensor([[ 69.,  96.,  70.],
#         [103.,  43.,  36.],
#         [ 68.,  96.,  71.],
#         [ 92.,  87.,  64.],
#         [ 87., 134.,  58.]])
# tensor([[103., 119.],
#         [ 20.,  38.],
#         [104., 118.],
#         [ 82., 100.],
#         [119., 133.]])
# tensor([[101.,  44.,  37.],
#         [ 74.,  66.,  43.],
#         [ 91.,  87.,  65.],
#         [ 91.,  88.,  64.],
#         [ 73.,  66.,  44.]])
# tensor([[ 21.,  38.],
#         [ 57.,  69.],
#         [ 80., 102.],
#         [ 81., 101.],
#         [ 57.,  69.]])
# tensor([[ 68.,  97.,  70.],
#         [ 87., 135.,  57.],
#         [ 73.,  67.,  43.],
#         [ 88., 134.,  59.],
#         [102.,  43.,  37.]])
# tensor([[102., 120.],
#         [118., 134.],
#         [ 56.,  70.],
#         [118., 132.],
#         [ 22.,  37.]])

# %% [markdown]
# In each iteration, the data loader returns one batch of data with the given batch size. If `shuffle` is set to `True`, it shuffles the training data before creating batches. Shuffling helps randomize the input to the optimization algorithm, leading to a faster reduction in the loss.

# %% [markdown]
# ## nn.Linear
#
# Instead of initializing the weights & biases manually, we can define the model using the `nn.Linear` class from PyTorch, which does it automatically.

# %%
mod = nn.Linear(10, 20)
x = torch.randn(120, 10)
mod(x).shape
mod.weight.shape
# Out:
# torch.Size([20, 10])

# %%
# Define model
model = nn.Linear(3, 2)
print(model.weight)
print(model.bias)
# Out:
# Parameter containing:
# tensor([[-0.4430, -0.4291, -0.5525],
#         [-0.0619,  0.2994, -0.4069]], requires_grad=True)
# Parameter containing:
# tensor([0.0037, 0.4808], requires_grad=True)

# %% [markdown]
# PyTorch models also have a helpful `.parameters` method, which returns a list containing all the weights and bias matrices present in the model. For our linear regression model, we have one weight matrix and one bias matrix.

# %%
# Parameters
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[-0.4430, -0.4291, -0.5525],
#          [-0.0619,  0.2994, -0.4069]], requires_grad=True),
#  Parameter containing:
#  tensor([0.0037, 0.4808], requires_grad=True)]

# %%
print(model)
# Out:
# Linear(in_features=3, out_features=2, bias=True)

# %% [markdown]
# We can use the model to generate predictions in the same way as before.

# %%
# Generate predictions
preds = model(inputs)
preds
# Out:
# tensor([[ -84.8383,   -1.4743],
#         [-113.4245,   -4.8457],
#         [-128.0757,   11.6178],
#         [ -84.0717,   -8.0156],
#         [-110.4266,   -3.5290],
#         [ -84.8522,   -1.8357],
#         [-113.5479,   -5.5520],
#         [-129.0711,   11.1490],
#         [ -84.0578,   -7.6542],
#         [-110.5361,   -3.8739],
#         [ -84.9617,   -2.1806],
#         [-113.4384,   -5.2070],
#         [-127.9523,   12.3241],
#         [ -83.9622,   -7.6706],
#         [-110.4127,   -3.1676]], grad_fn=<AddmmBackward>)

# %% [markdown]
# ## Loss Function
#
# Instead of defining a loss function manually, we can use the built-in loss function `mse_loss`.

# %%
# Import nn.functional
import torch.nn.functional as F

# %% [markdown]
# The `nn.functional` package contains many useful loss functions and several other utilities.

# %%
# Define loss function
loss_fn = F.mse_loss

# %% [markdown]
# Let's compute the loss for the current predictions of our model.

# %%
loss = loss_fn(model(inputs), targets)
print(loss)
# Out:
# tensor(22345.0996, grad_fn=<MseLossBackward>)

# %% [markdown]
# ## Optimizer
#
# Instead of manually manipulating the model's weights & biases using gradients, we can use the optimizer `optim.SGD`. SGD is short for "stochastic gradient descent". The term _stochastic_ indicates that samples are selected in random batches instead of as a single group.

# %%
torch.optim.SGD?

# %%
# Define optimizer
opt = torch.optim.SGD(model.parameters(), lr=1e-5)

# %% [markdown]
# Note that `model.parameters()` is passed as an argument to `optim.SGD` so that the optimizer knows which matrices should be modified during the update step. Also, we can specify a learning rate that controls the amount by which the parameters are modified.

# %% [markdown]
# ## Train the model
#
# We are now ready to train the model. We'll follow the same process to implement gradient descent:
#
# 1. Generate predictions
#
# 2. Calculate the loss
#
# 3. Compute gradients w.r.t the weights and biases
#
# 4. Adjust the weights by subtracting a small quantity proportional to the gradient
#
# 5. Reset the gradients to zero
#
# The only change is that we'll work batches of data instead of processing the entire training data in every iteration. Let's define a utility function `fit` that trains the model for a given number of epochs.

# %%
# Utility function to train the model
def fit(num_epochs, model, loss_fn, opt, train_dl):
    
    # Repeat for given number of epochs
    for epoch in range(num_epochs):
        
        # Train with batches of data
        for xb,yb in train_dl:
            
            # 1. Generate predictions
            pred = model(xb)
            
            # 2. Calculate loss
            loss = loss_fn(pred, yb)
            
            # 3. Compute gradients
            loss.backward()
            
            # 4. Update parameters using gradients
            opt.step()
            
            # 5. Reset the gradients to zero
            opt.zero_grad()
        
        # Print the progress
        if (epoch+1) % 10 == 0:
            print('Epoch [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, loss.item()))

# %% [markdown]
# Some things to note above:
#
# * We use the data loader defined earlier to get batches of data for every iteration.
#
# * Instead of updating parameters (weights and biases) manually, we use `opt.step` to perform the update and `opt.zero_grad` to reset the gradients to zero.
#
# * We've also added a log statement that prints the loss from the last batch of data for every 10th epoch to track training progress. `loss.item` returns the actual value stored in the loss tensor.
#
# Let's train the model for 100 epochs.

# %%
fit(100, model, loss_fn, opt, train_dl)
# Out:
# Epoch [10/100], Loss: 435.4972
# Epoch [20/100], Loss: 237.5329
# Epoch [30/100], Loss: 188.2681
# Epoch [40/100], Loss: 196.5939
# Epoch [50/100], Loss: 69.5989
# Epoch [60/100], Loss: 20.8738
# Epoch [70/100], Loss: 132.6108
# Epoch [80/100], Loss: 88.3055
# Epoch [90/100], Loss: 52.3942
# Epoch [100/100], Loss: 72.9758

# %% [markdown]
# Let's generate predictions using our model and verify that they're close to our targets.

# %%
# Generate predictions
preds = model(inputs)
preds
# Out:
# tensor([[ 58.4838,  71.9020],
#         [ 79.6122,  95.9247],
#         [122.0940, 141.8526],
#         [ 28.6866,  44.6918],
#         [ 92.9980, 106.4502],
#         [ 57.3446,  70.8254],
#         [ 78.9162,  95.0870],
#         [122.1338, 141.9714],
#         [ 29.8257,  45.7683],
#         [ 93.4412, 106.6890],
#         [ 57.7878,  71.0642],
#         [ 78.4730,  94.8482],
#         [122.7900, 142.6903],
#         [ 28.2434,  44.4529],
#         [ 94.1371, 107.5267]], grad_fn=<AddmmBackward>)

# %%
# Compare with targets
targets
# Out:
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.],
#         [ 57.,  69.],
#         [ 80., 102.],
#         [118., 132.],
#         [ 21.,  38.],
#         [104., 118.],
#         [ 57.,  69.],
#         [ 82., 100.],
#         [118., 134.],
#         [ 20.,  38.],
#         [102., 120.]])

# %% [markdown]
# Indeed, the predictions are quite close to our targets. We have a trained a reasonably good model to predict crop yields for apples and oranges by looking at the average temperature, rainfall, and humidity in a region. We can use it to make predictions of crop yields for new regions by passing a batch containing a single row of input.

# %%
model(torch.tensor([[75, 63, 44.]]))
# Out:
# tensor([[54.5720, 67.8946]], grad_fn=<AddmmBackward>)

# %% [markdown]
# The predicted yield of apples is 54.3 tons per hectare, and that of oranges is 68.3 tons per hectare.

# %%
F.mse_loss(model(inputs),targets)**0.5
# Out:
# tensor(7.0775, grad_fn=<PowBackward0>)

# %% [markdown]
# ## Machine Learning vs. Classical Programming
#
# The approach we've taken in this tutorial is very different from programming as you might know it. Usually, we write programs that take some inputs, perform some operations, and return a result.
#
# However, in this notebook, we've defined a "model" that assumes a specific relationship between the inputs and the outputs, expressed using some unknown parameters (weights & biases). We then show the model some know inputs and outputs and _train_ the model to come up with good values for the unknown parameters. Once trained, the model can be used to compute the outputs for new inputs.
#
# This paradigm of programming is known as _machine learning_, where we use data to figure out the relationship between inputs and outputs. _Deep learning_ is a branch of machine learning that uses matrix operations, non-linear activation functions and gradient descent to build and train models. Andrej Karpathy, the director of AI at Tesla Motors, has written a great blog post on this topics, titled [Software 2.0](https://medium.com/@karpathy/software-2-0-a64152b37c35).
#
# This picture from book [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python) by Francois Chollet captures the difference between classical programming and machine learning:
#
# ![](https://i.imgur.com/oJEQe7k.png)
#
# Keep this picture in mind as you work through the next few tutorials.

# %% [markdown]
# ## Exercises and Further Reading
#
# We've covered the following topics in this tutorial:
#
# - Introduction to linear regression and gradient descent
# - Implementing a linear regression model using PyTorch tensors
# - Training a linear regression model using the gradient descent algorithm
# - Implementing gradient descent and linear regression using PyTorch built-in
#
#
# Here are some resources for learning more about linear regression and gradient descent:
#
# * An visual & animated explanation of gradient descent: https://www.youtube.com/watch?v=IHZwWFHWa-w
#
# * For a more detailed explanation of derivates and gradient descent, see [these notes from a Udacity course](https://storage.googleapis.com/supplemental_media/udacityu/315142919/Gradient%20Descent.pdf).
#
# * For an animated visualization of how linear regression works, [see this post](https://hackernoon.com/visualizing-linear-regression-with-pytorch-9261f49edb09).
#
# * For a more mathematical treatment of matrix calculus, linear regression and gradient descent, you should check out [Andrew Ng's excellent course notes](https://github.com/Cleo-Stanford-CS/CS229_Notes/blob/master/lectures/cs229-notes1.pdf) from CS229 at Stanford University.
#
# * To practice and test your skills, you can participate in the [Boston Housing Price Prediction](https://www.kaggle.com/c/boston-housing) competition on Kaggle, a website that hosts data science competitions.
#
# With this, we complete our discussion of linear regression in PyTorch, and we’re ready to move on to the next topic: [Working with Images & Logistic Regression](https://jovian.ai/aakashns/03-logistic-regression).

# %% [markdown]
# ## Questions for Review
#
# Try answering the following questions to test your understanding of the topics covered in this notebook:
#
# 1. What is a linear regression model? Give an example of a problem formulated as a linear regression model.
# 2. What are input and target variables in a dataset? Give an example.
# 3. What are weights and biases in a linear regression model?
# 4. How do you represent tabular data using PyTorch tensors?
# 5. Why do we create separate matrices for inputs and targets while training a linear regression model?
# 6. How do you determine the shape of the weights matrix & bias vector given some training data?
# 7. How do you create randomly initialized weights & biases with a given shape?
# 8. How is a linear regression model implemented using matrix operations? Explain with an example.
# 9. How do you generate predictions using a linear regression model?
# 10. Why are the predictions of a randomly initialized model different from the actual targets?
# 11. What is a loss function? What does the term “loss” signify?
# 12. What is mean squared error?
# 13. Write a function to calculate mean squared using model predictions and actual targets.
# 14. What happens when you invoke the `.backward` function on the result of the mean squared error loss function?
# 15. Why is the derivative of the loss w.r.t. the weights matrix itself a matrix? What do its elements represent?
# 16. How is the derivate of the loss w.r.t. a weight element useful for reducing the loss? Explain with an example.
# 17. Suppose the derivative  of the loss w.r.t. a weight element is positive. Should you increase or decrease the element’s value slightly to get a lower loss?
# 18. Suppose the derivative  of the loss w.r.t. a weight element is negative. Should you increase or decrease the element’s value slightly to get a lower loss?
# 19. How do you update the weights and biases of a model using their respective gradients to reduce the loss slightly?
# 20. What is the gradient descent optimization algorithm? Why is it called “gradient descent”?
# 21. Why do you subtract a “small quantity” proportional to the gradient from the weights & biases, not the actual gradient itself?
# 22. What is learning rate? Why is it important?
# 23. What is `torch.no_grad`?
# 24. Why do you reset gradients to zero after updating weights and biases?
# 25. What are the steps involved in training a linear regression model using gradient descent?
# 26. What is an epoch?
# 27. What is the benefit of training a model for multiple epochs?
# 28. How do you make predictions using a trained model?
# 29. What should you do if your model’s loss doesn’t decrease while training? Hint: learning rate.
# 30. What is `torch.nn`?
# 31. What is the purpose of the `TensorDataset` class in PyTorch? Give an example.
# 32. What is a data loader in PyTorch? Give an example.
# 33. How do you use a data loader to retrieve batches of data?
# 34. What are the benefits of shuffling the training data before creating batches?
# 35. What is the benefit of training in small batches instead of training with the entire dataset?
# 36. What is the purpose of the `nn.Linear` class in PyTorch? Give an example.
# 37. How do you see the weights and biases of a `nn.Linear` model?
# 38. What is the purpose of the `torch.nn.functional` module?
# 39. How do you compute mean squared error loss using a PyTorch built-in function?
# 40. What is an optimizer in PyTorch?
# 41. What is `torch.optim.SGD`? What does SGD stand for?
# 42. What are the inputs to a PyTorch optimizer?
# 43. Give an example of creating an optimizer for training a linear regression model.
# 44. Write a function to train a `nn.Linear` model in batches using gradient descent.
# 45. How do you use a linear regression model to make predictions on previously unseen data?
